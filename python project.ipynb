# %%
def enter_rec(det):
  id=input("Enter Customer Id")
  name=input("Enter Customer name")
  cash_balance=float(input("Enter cash balance"))
  pin=int(input("Generate Pin"))
  l=[id,name,cash_balance,pin]
  det.append(l)
  print("Your record was successfully updated!")

def id_rec(det):
    l=[]
    for i in det:
        l.append(i[0])
    return l
        
    
def records(det,rec):
    for i in det:
        if i not in rec:
          list1=[]
          for j in range(3):
              list1.append(i[j])
          rec.append(list1)
    return rec
            
def cash_withdrawal(det,l):
  id=input("Enter customer Id")
  if id in l:
      amt=int(input("Enter amount"))
      pin=int(input("Enter your pin"))
      for i in det:
          if id==i[0] and pin == int(i[3]):
              print("Collect your cash, your balance amount is", i[2]-amt)
              break
          else:
              print("Wrong pin entered")
              break
  else:
      print("Invalid Id")
def show_rec(rec,l):
  id=input("Enter your customer id")
  if id in l:
      for i in rec:
          if i[0]==id:
              print(i)
              break
  else:
      print("Invalid id")

def change_pin(det,l):
   id=input("Enter your customer id")
   if id in l:
       op=input("Enter old pin")
       np=input("Enter new pin")
       cp=input("Confirm new pin")
       for i in det:
           if i[0]==id:
               i[3]=cp
               print("Pin successfully changed!")
   else:
       print("invalid id")
   
det=[["123","Anushka",56231.90, "0704"],["125","Priya",79845,"1003"],["456","Diya",56321,"2809"]]
rec=[]
rec=records(det,rec)
print("\t\t************BANK MANAGEMENT SYSTEM************* \t\t\t\t\t\t\t\t\n")

flag=True
while flag == True:
    l=id_rec(det)
    ch=input("(1)Enter a record[A]\n(2)View details[B]\n(3)Cash withdrawal[C]\n(4)Change pin[D]\nEnter your choice(A/B/C/D)")
    if ch == "A" or ch == "a":
      enter_rec(det)
      records(det,rec)
      id_rec(det)
      
    elif ch=="B" or ch == "b":
        show_rec(rec,l)

    elif ch == "C" or ch == "c":
        cash_withdrawal(det,l)

    elif ch == "D" or ch == "d":
        change_pin(det,l)
    else:
        print("Invalid input!")

    re=input("\nDo you want to re-enter your choice?(Y/N)")
    if re=="y" or re=="Y":
         flag = True
    elif re == "N" or re=="n":
         print("THANKS FOR VISITING! DO VISIT US AGAIN!")
         flag = False
    else:
         print("Invalid input")
         break

# %%
# Out:
# Write Your paragraph/essay:Paragraph On Friendship: A friend keeps a lot of importance in our life, and everybody enjoys the company of a friend. True friendship is tough to get. Through every hardship and failure, the faithful friend will stand by. They will care for you every time, and gaining a true friendship is a real present.
# Options: 1. Number of words in paragraph/essay
#  2. Number of sentences in paragraph/essay
#  3. Most frequent words in paragraph/essay
# Choose any of the options:2
# Number Of Sentences In Paragraph/Essay: 4
# +----------------------------------------+----------+
# | Calculation of:                        | Values   |
# +========================================+==========+
# | Number of words in paragraph-          | 54       |
# +----------------------------------------+----------+
# | Number of sentences in paragraph-      | 4        |
# +----------------------------------------+----------+
# | Most frequent words used in paragraph- | ('a', 4) |
# +----------------------------------------+----------+

# %%
# Out:
# Write Your paragraph/essay:A friend keeps a lot of importance in our life, and everybody enjoys the company of a friend. True friendship is tough to get. Through every hardship and failure, the faithful friend will stand by. They will care for you every time, and gaining a true friendship is a real present.
# Options: 1. Number of words in paragraph/essay
#  2. Number of sentences in paragraph/essay
#  3. Most frequent words in paragraph/essay
#  4. Tabular form
# Choose any of the options:3
# Most Frequent Words Used In Paragraph/Essay: ('a', 4)
